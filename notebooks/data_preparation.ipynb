# %%
import pandas as pd
import numpy as np
# Viz
import seaborn as sns
import matplotlib.pyplot as plt
# stat tests
import scipy as sp
from scipy.stats import pearsonr, spearmanr
# system lib
import os
import sys

# dataset 
from sklearn.datasets import load_breast_cancer
print("All is okeyy !")
# Out:
# All is okeyy !

# %%
# load our dataset
data = load_breast_cancer()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = data.target
df.head(3)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38           122.8     1001.0          0.11840
# 1        20.57         17.77           132.9     1326.0          0.08474
# 2        19.69         21.25           130.0     1203.0          0.10960
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33            184.6      2019.0
# 1                 0.05667  ...          23.41            158.8      1956.0
# 2                 0.05999  ...          25.53            152.5      1709.0
#
# ...

# %% [markdown]
# ## EAD Pipeline

# %%
print(os.getcwd())
# Ajouter le dossier parent du dossier courant dans sys.path
parent_path = os.path.abspath('..')  # un niveau au-dessus du dossier courant
if parent_path not in sys.path:
    sys.path.append(parent_path)
# Out:
# c:\Users\Zakaria-Laptop\linear_models\notebooks

# %%
from src.ead_pipeline import EAD_Dataframe

# create a copy of our dataframe
df_copy = df.copy()

# %%
ead_pipeline = EAD_Dataframe(df_copy)
new_df1 = ead_pipeline.df
ead_pipeline.run_pipeline()
# Out:
# [INFO] - List of columns in our dataframe is: ['mean radius', 'mean texture', 'mean perimeter', 'mean area', 'mean smoothness', 'mean compactness', 'mean concavity', 'mean concave points', 'mean symmetry', 'mean fractal dimension', 'radius error', 'texture error', 'perimeter error', 'area error', 'smoothness error', 'compactness error', 'concavity error', 'concave points error', 'symmetry error', 'fractal dimension error', 'worst radius', 'worst texture', 'worst perimeter', 'worst area', 'worst smoothness', 'worst compactness', 'worst concavity', 'worst concave points', 'worst symmetry', 'worst fractal dimension', 'target']
# [INFO] - The size of our dataframe is: (569, 31)
# [INFO] - Sum of null rows is: (0, 31)
# [INFO] - Sum of duplicates rows: (0, 32)
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# ...

# %% [markdown]
# ## Preprocessing Pipeline

# %%
from src.preprocessing_pipeline import PreProcessing

# %%
pipeline_preprocessing = PreProcessing(new_df1)
new_df2 = pipeline_preprocessing.df
pipeline_preprocessing.run_pipeline_preprocessing()
# Out:
# [INFO] Outliers détectés : 12
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          25.22         39.28          171.50     1878.0          0.16340
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %% [markdown]
# ## Selection de variables

# %%
from src.features_selection_pipeline import FeaturesSeelectionPipeline

# %%
feature_selector = FeaturesSeelectionPipeline(new_df2)
list_finale_features = feature_selector.list_uncorrelated_features()

# %%
list_finale_features
# Out:
# ['mean radius',
#  'mean texture',
#  'mean smoothness',
#  'mean compactness',
#  'mean symmetry',
#  'mean fractal dimension',
#  'texture error',
#  'smoothness error',
#  'symmetry error',
#  'worst symmetry']

# %%
# Finale dataset
target_name = ["target"]
features_names = list_finale_features
new_df3 = new_df2[features_names + target_name]
new_df3
# Out:
#      mean radius  mean texture  mean smoothness  mean compactness  \
# 0          17.99         10.38          0.11840           0.27760
# 1          20.57         17.77          0.08474           0.07864
# 2          19.69         21.25          0.10960           0.15990
# 3          11.42         20.38          0.14250           0.28390
# 4          20.29         14.34          0.10030           0.13280
# ..           ...           ...              ...               ...
# 564        21.56         22.39          0.11100           0.11590
# 565        20.13         28.25          0.09780           0.10340
# 566        16.60         28.08          0.08455           0.10230
# 567        20.60         29.33          0.11780           0.27700
# 568         7.76         24.54          0.05263           0.04362
#
#      mean symmetry  mean fractal dimension  texture error  smoothness error  \
# 0           0.2419                 0.07871         0.9053          0.006399
# ...

# %% [markdown]
# ## Statistique et feature engineer

# %%
from scipy.stats import skew
dict_skewness = {}
for col in features_names:
    s = skew(new_df3[col])
    if abs(s)>1:
        dict_skewness[col] = s
dict_skewness
# Out:
# {'mean compactness': 1.186983323974523,
#  'mean fractal dimension': 1.3010473927890858,
#  'texture error': 1.6421002649479612,
#  'smoothness error': 2.308344221045982,
#  'symmetry error': 2.189341838925834,
#  'worst symmetry': 1.4301448677540645}

# %%
# transform this variables with log(1+x)
def transformer(x):
    return np.log(1+x)

def trans2(x):
    return np.sqrt(x)

new_df4 = new_df3.copy()

for col in dict_skewness.keys():
    new_df4[col] = new_df4[col].transform(trans2)
    new_name = 'tran_'+str(col)
    new_df4 = new_df4.rename(columns={col: new_name})

# %%
from scipy.stats import skew
new_dict_skewness = {}
for col in new_df4.columns:
    s = skew(new_df4[col])
    if abs(s)>1:
        new_dict_skewness[col] = s
new_dict_skewness
# Out:
# {'tran_mean fractal dimension': 1.065246907805465,
#  'tran_smoothness error': 1.2034573410125455,
#  'tran_symmetry error': 1.3398675910226285}

# %%
new_df4
# Out:
#      mean radius  mean texture  mean smoothness  tran_mean compactness  \
# 0          17.99         10.38          0.11840               0.526878
# 1          20.57         17.77          0.08474               0.280428
# 2          19.69         21.25          0.10960               0.399875
# 3          11.42         20.38          0.14250               0.532823
# 4          20.29         14.34          0.10030               0.364417
# ..           ...           ...              ...                    ...
# 564        21.56         22.39          0.11100               0.340441
# 565        20.13         28.25          0.09780               0.321559
# 566        16.60         28.08          0.08455               0.319844
# 567        20.60         29.33          0.11780               0.526308
# 568         7.76         24.54          0.05263               0.208854
#
#      mean symmetry  tran_mean fractal dimension  tran_texture error  \
# ...

# %%
# Extract metadata and procceed data
# create a file of metadata
metadata = []
for col, skew in dict_skewness.items():
    transformation = "np.sqrt()" if skew>1 else None
    new_name = f"tran_{col}" if skew>1 else col
    metadata.append({
        "original_feature": col,
        "skewness": skew,
        "transformation" : transformation,
        "final column name": new_name
    })

df_metadata = pd.DataFrame(metadata)

# %%
"""# Créer le dossier ../data à la racine du projet si besoin
os.makedirs("../data", exist_ok=True)

# Exportation des fichiers dans le dossier ../data
with open("../data/final_dataset.csv", mode="w", encoding='utf-8', newline='') as f_data, \
     open("../data/transformations_metadata.csv", mode="w", encoding='utf-8', newline='') as f_meta:
    
    new_df4.to_csv(f_data, index=False)
    df_metadata.to_csv(f_meta, index=False)"""
