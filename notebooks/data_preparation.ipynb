# %%
import pandas as pd
import numpy as np
# Viz
import seaborn as sns
import matplotlib.pyplot as plt
# stat tests
import scipy as sp
from scipy.stats import pearsonr, spearmanr
# system lib
import os
import sys

# dataset 
from sklearn.datasets import load_breast_cancer
print("All is okeyy !")
# Out:
# All is okeyy !

# %%
# load our dataset
data = load_breast_cancer()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = data.target
df.head(3)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38           122.8     1001.0          0.11840
# 1        20.57         17.77           132.9     1326.0          0.08474
# 2        19.69         21.25           130.0     1203.0          0.10960
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33            184.6      2019.0
# 1                 0.05667  ...          23.41            158.8      1956.0
# 2                 0.05999  ...          25.53            152.5      1709.0
#
# ...

# %% [markdown]
# ## EAD Pipeline

# %%
print(os.getcwd())
# Ajouter le dossier parent du dossier courant dans sys.path
parent_path = os.path.abspath('..')  # un niveau au-dessus du dossier courant
if parent_path not in sys.path:
    sys.path.append(parent_path)
# Out:
# c:\Users\Zakaria-Laptop\linear_models\notebooks

# %%
from src.ead_pipeline import EAD_Dataframe

# create a copy of our dataframe
df_copy = df.copy()

# %%
ead_pipeline = EAD_Dataframe(df_copy)
new_df1 = ead_pipeline.df
ead_pipeline.run_pipeline()
# Out:
# [INFO] - List of columns in our dataframe is: ['mean radius', 'mean texture', 'mean perimeter', 'mean area', 'mean smoothness', 'mean compactness', 'mean concavity', 'mean concave points', 'mean symmetry', 'mean fractal dimension', 'radius error', 'texture error', 'perimeter error', 'area error', 'smoothness error', 'compactness error', 'concavity error', 'concave points error', 'symmetry error', 'fractal dimension error', 'worst radius', 'worst texture', 'worst perimeter', 'worst area', 'worst smoothness', 'worst compactness', 'worst concavity', 'worst concave points', 'worst symmetry', 'worst fractal dimension', 'target']
# [INFO] - The size of our dataframe is: (569, 31)
# [INFO] - Sum of null rows is: (0, 31)
# [INFO] - Sum of duplicates rows: (0, 32)
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# ...

# %% [markdown]
# ## Preprocessing Pipeline

# %%
from src.preprocessing_pipeline import PreProcessing

# %%
pipeline_preprocessing = PreProcessing(new_df1)
new_df2 = pipeline_preprocessing.df
pipeline_preprocessing.run_pipeline_preprocessing()
# Out:
# [INFO] Outliers détectés : 12
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          25.22         39.28          171.50     1878.0          0.16340
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %% [markdown]
# ## Selection de variables

# %%
def pearson_correlation(df):

    columns = df.columns.to_list()
    results = {}
    for i in range(len(columns)):
        col_i = columns[i]
        df_col_i = df[col_i]
        results[col_i] = []
        for j in range(i+1, len(columns)):
            col_j = columns[j]
            df_col_j = df[col_j]
            corr,  p_value = pearsonr(df_col_i, df_col_j)
            if abs(corr) >0.7 and p_value<0.05:
                results[col_i].append((col_j, corr, p_value))
            else:
                pass
    return results

# %%
results_corr = pearson_correlation(new_df2)

# %%
all_cols = new_df2.columns.to_list()
def drop_multicolinearity(all_columns, results_corr):
    to_remove = set()
    for _, corr_list in results_corr.items():
        for col_corr, _, _ in corr_list:
            to_remove.add(col_corr)
    
    selected_features = [col for col in all_columns if col not in to_remove]
    return selected_features

# %%
finale_selection = drop_multicolinearity(all_cols, results_corr)

# %%
finale_selection
# Out:
# ['mean radius',
#  'mean texture',
#  'mean smoothness',
#  'mean compactness',
#  'mean symmetry',
#  'mean fractal dimension',
#  'texture error',
#  'smoothness error',
#  'symmetry error',
#  'worst symmetry']
